# %%
from scipy.optimize import least_squares, minimize
import numpy as np
import matplotlib.pyplot as plt
from toy_datasets import ToyDatasets
from scipy.stats import norm

# %%
class Stage4Algorithm():
  def __init__(self, num_elements, h_order, ar_order):
    self.num_elements = num_elements
    self.h_order, self.ar_order = h_order, ar_order
    self.X, self.G, self.K = None, None, None
    self.dims = None

  def hankelise(self, x, order):
    hankel_matrix = np.zeros((order, x.shape[1] - order + 1))
    for i in range(order):
      hankel_matrix[i, :] = x[0, i:i+x.shape[1]-order+1]
    return hankel_matrix

  def objective(self, params):
    (X_shape, X_len), (G_shape, G_len), (K_shape, K_len) = self.dims
    X, G = params[:X_len], params[X_len:(X_len+G_len)]
    X, G = X.reshape(X_shape), G.reshape(G_shape)
    result = 0.5 * (np.linalg.norm(G, 'fro') ** 2)
    return result.flatten()

  def hankel_constraint(self, params):
    (X_shape, X_len), (G_shape, G_len), (K_shape, K_len) = self.dims
    X, K = params[:X_len], params[(X_len+G_len):]
    X, K = X.reshape(X_shape), K.reshape(K_shape)
    X1, X2 = X[:, :-1], X[:, 1:]
    X1, X2 = self.hankelise(X1, self.ar_order), self.hankelise(X2, self.ar_order)
    return (X2 - K @ X1).flatten()

  def D_constraint(self, params, D):
    (X_shape, X_len), (G_shape, G_len), (K_shape, K_len) = self.dims
    X, G = params[:X_len], params[X_len:(X_len+G_len)]
    X, G = X.reshape(X_shape), G.reshape(G_shape)
    return (D - X - G).flatten()
    
  def fit(self, D):
    X_initial_guess, G_initial_guess, K_initial_guess = \
      D, np.zeros(D.shape), np.zeros((self.ar_order, self.ar_order))
    for i in range(self.ar_order-1):
      K_initial_guess[i, i+1] = 1
    params = np.concatenate([X_initial_guess.flatten(), G_initial_guess.flatten(), K_initial_guess.flatten()])
    dims = (
      (X_initial_guess.shape, len(X_initial_guess.flatten())),
      (G_initial_guess.shape, len(G_initial_guess.flatten())),
      (K_initial_guess.shape, len(K_initial_guess.flatten()))
    )
    self.dims = dims
    constraints = (
      {'type': 'eq', 'fun': self.hankel_constraint},
      {'type': 'eq', 'fun': self.D_constraint, 'args': (D,)},
    )
    result = minimize(self.objective, params, constraints=constraints, method='trust-constr')
    (X_shape, X_len), (G_shape, G_len), (K_shape, K_len) = self.dims
    X, G, K = result.x[:X_len], result.x[X_len:(X_len+G_len)], result.x[(X_len+G_len):]
    X, G, K = X.reshape(X_shape), G.reshape(G_shape), K.reshape(K_shape)[-1]
    self.X, self.G, self.K = X, G, K

  def predict(self, x):
    y_predicted = []
    for i in range(x.shape[1] - self.ar_order):
      y_predicted.append(np.dot(x.flatten()[i:i+self.ar_order], self.K).flatten()[0])
    return y_predicted

  def forecast(self, x, timesteps):
    current_window = x[:, -self.ar_order:]
    forecasted = []
    for i in range(timesteps):
      next_el = np.dot(current_window.flatten(), self.K).flatten()[0]
      forecasted.append(next_el)
      current_window = np.append(current_window, next_el)[1:]
    return forecasted
  
  def evaluate(self, y, y_predicted):
    return np.sqrt(1/len(y) * np.sum(np.square(y - y_predicted)))

# %%
num_elements = 200
toy_datasets = ToyDatasets(num_elements=num_elements)

# %%
np.random.seed(0)
order = 3
test_len = 10
toy_data = toy_datasets.stationary_with_gaussian_noise().reshape(-1, 1).T
train_data, test_data = toy_data[:, :toy_data.shape[1]-test_len], toy_data[:, toy_data.shape[1]-test_len:]
alg = Stage4Algorithm(num_elements=num_elements, h_order=20, ar_order=order)
alg.fit(train_data)
fitted = alg.X
forecasted = alg.forecast(fitted, test_len)
plt.plot(range(train_data.shape[1]), train_data.flatten(), label="True Train")
plt.plot(range(train_data.shape[1]), fitted.flatten(), label="Fitted")
plt.plot(range(train_data.shape[1], train_data.shape[1]+test_data.shape[1]), test_data.flatten(), label="True Test")
plt.plot(range(train_data.shape[1], train_data.shape[1]+test_data.shape[1]), forecasted, label="Forecast")
plt.title("Stage 4 Algorithm: Stationary with Gaussian Noise")
plt.legend()
plt.show()
accuracy = alg.evaluate(test_data, forecasted)
print("RMSE: ", accuracy)
# Out:
# c:\Users\chris\fyp\venv\lib\site-packages\scipy\optimize\_trustregion_constr\equality_constrained_sqp.py:80: UserWarning: Singular Jacobian matrix. Using SVD decomposition to perform the factorizations.
#   Z, LS, Y = projections(A, factorization_method)
# c:\Users\chris\fyp\venv\lib\site-packages\scipy\optimize\_differentiable_functions.py:504: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   self.H.update(delta_x, delta_g)
# c:\Users\chris\fyp\venv\lib\site-packages\scipy\optimize\_trustregion_constr\equality_constrained_sqp.py:203: UserWarning: Singular Jacobian matrix. Using SVD decomposition to perform the factorizations.
#   Z, LS, Y = projections(A, factorization_method)
# RMSE:  0.34188847778253134

# %%
num_elements = 100
toy_datasets = ToyDatasets(num_elements=num_elements)
np.random.seed(0)
order = 3
test_len = 10
toy_data = toy_datasets.linear_trending_with_gaussian_noise().reshape(-1, 1).T
train_data, test_data = toy_data[:, :toy_data.shape[1]-test_len], toy_data[:, toy_data.shape[1]-test_len:]
alg = Stage4Algorithm(num_elements=num_elements, h_order=20, ar_order=order)
alg.fit(train_data)
fitted = alg.X
forecasted = alg.forecast(fitted, test_len)
plt.plot(range(train_data.shape[1]), train_data.flatten(), label="True Train")
plt.plot(range(train_data.shape[1]), fitted.flatten(), label="Fitted")
plt.plot(range(train_data.shape[1], train_data.shape[1]+test_data.shape[1]), test_data.flatten(), label="True Test")
plt.plot(range(train_data.shape[1], train_data.shape[1]+test_data.shape[1]), forecasted, label="Forecast")
plt.title("Stage 4 Algorithm: Stationary with Gaussian Noise")
plt.legend()
plt.show()
accuracy = alg.evaluate(test_data, forecasted)
print("RMSE: ", accuracy)
# Out:
# RMSE:  0.19957793553491787

# %%
num_elements = 100
toy_datasets = ToyDatasets(num_elements=num_elements)
np.random.seed(0)
order = 3
test_len = 10
toy_data = toy_datasets.periodical_sinusoidal_with_gaussian_noise().reshape(-1, 1).T
train_data, test_data = toy_data[:, :toy_data.shape[1]-test_len], toy_data[:, toy_data.shape[1]-test_len:]
alg = Stage4Algorithm(num_elements=num_elements, h_order=20, ar_order=order)
alg.fit(train_data)
fitted = alg.X
forecasted = alg.forecast(fitted, test_len)
plt.plot(range(train_data.shape[1]), train_data.flatten(), label="True Train")
plt.plot(range(train_data.shape[1]), fitted.flatten(), label="Fitted")
plt.plot(range(train_data.shape[1], train_data.shape[1]+test_data.shape[1]), test_data.flatten(), label="True Test")
plt.plot(range(train_data.shape[1], train_data.shape[1]+test_data.shape[1]), forecasted, label="Forecast")
plt.title("Stage 4 Algorithm: Stationary with Gaussian Noise")
plt.legend()
plt.show()
accuracy = alg.evaluate(test_data, forecasted)
print("RMSE: ", accuracy)
# Out:
# c:\Users\chris\fyp\venv\lib\site-packages\scipy\optimize\_trustregion_constr\equality_constrained_sqp.py:80: UserWarning: Singular Jacobian matrix. Using SVD decomposition to perform the factorizations.
#   Z, LS, Y = projections(A, factorization_method)
# c:\Users\chris\fyp\venv\lib\site-packages\scipy\optimize\_differentiable_functions.py:504: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   self.H.update(delta_x, delta_g)
# c:\Users\chris\fyp\venv\lib\site-packages\scipy\optimize\_trustregion_constr\equality_constrained_sqp.py:203: UserWarning: Singular Jacobian matrix. Using SVD decomposition to perform the factorizations.
#   Z, LS, Y = projections(A, factorization_method)
# RMSE:  6.805653527405295

# %%
num_elements = 30
toy_datasets = ToyDatasets(num_elements=num_elements)
np.random.seed(0)
order = 10
test_len = 10
toy_data = toy_datasets.periodical_sinusoidal_with_gaussian_noise().reshape(-1, 1).T
train_data, test_data = toy_data[:, :toy_data.shape[1]-test_len], toy_data[:, toy_data.shape[1]-test_len:]
alg = Stage4Algorithm(num_elements=num_elements, h_order=20, ar_order=order)
alg.fit(train_data)
fitted = alg.X
forecasted = alg.forecast(fitted, test_len)
plt.plot(range(train_data.shape[1]), train_data.flatten(), label="True Train")
plt.plot(range(train_data.shape[1]), fitted.flatten(), label="Fitted")
plt.plot(range(train_data.shape[1], train_data.shape[1]+test_data.shape[1]), test_data.flatten(), label="True Test")
plt.plot(range(train_data.shape[1], train_data.shape[1]+test_data.shape[1]), forecasted, label="Forecast")
plt.title("Stage 4 Algorithm: Stationary with Gaussian Noise")
plt.legend()
plt.show()
accuracy = alg.evaluate(test_data, forecasted)
print("RMSE: ", accuracy)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[118], line 9
#       7 train_data, test_data = toy_data[:, :toy_data.shape[1]-test_len], toy_data[:, toy_data.shape[1]-test_len:]
#       8 alg = Stage4Algorithm(num_elements=num_elements, h_order=20, ar_order=order)
# ----> 9 alg.fit(train_data)
#      10 fitted = alg.X
#      11 forecasted = alg.forecast(fitted, test_len)
#
# Cell In[116], line 51, in Stage4Algorithm.fit(self, D)
#      46 self.dims = dims
#      47 constraints = (
#      48   {'type': 'eq', 'fun': self.hankel_constraint},
#      49   {'type': 'eq', 'fun': self.D_constraint, 'args': (D,)},
#      50 )
# ---> 51 result = minimize(self.objective, params, constraints=constraints, method='trust-constr')
#      52 (X_shape, X_len), (G_shape, G_len), (K_shape, K_len) = self.dims
#      53 X, G, K = result.x[:X_len], result.x[X_len:(X_len+G_len)], result.x[(X_len+G_len):]
#
# File c:\Users\chris\fyp\venv\lib\site-packages\scipy\optimize\_minimize.py:725, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     722     res = _minimize_slsqp(fun, x0, args, jac, bounds,
#     723                           constraints, callback=callback, **options)
#     724 elif meth == 'trust-constr':
# --> 725     res = _minimize_trustregion_constr(fun, x0, args, jac, hess, hessp,
#     726                                        bounds, constraints,
#     727                                        callback=callback, **options)
#     728 elif meth == 'dogleg':
#     729     res = _minimize_dogleg(fun, x0, args, jac, hess,
#     730                            callback=callback, **options)
#
# File c:\Users\chris\fyp\venv\lib\site-packages\scipy\optimize\_trustregion_constr\minimize_trustregion_constr.py:519, in _minimize_trustregion_constr(fun, x0, args, grad, hess, hessp, bounds, constraints, xtol, gtol, barrier_tol, sparse_jacobian, callback, maxiter, verbose, finite_diff_rel_step, initial_constr_penalty, initial_tr_radius, initial_barrier_parameter, initial_barrier_tolerance, factorization_method, disp)
#     516         J_eq, _ = canonical.jac(x)
#     517         return g, J_eq
# --> 519     _, result = equality_constrained_sqp(
#     520         fun_and_constr, grad_and_jac, lagrangian_hess,
#     521         x0, objective.f, objective.g,
#     522         c_eq0, J_eq0,
#     523         stop_criteria, state,
#     524         initial_constr_penalty, initial_tr_radius,
#     525         factorization_method)
#     527 elif method == 'tr_interior_point':
#     528     _, result = tr_interior_point(
#     529         objective.fun, objective.grad, lagrangian_hess,
#     530         n_vars, canonical.n_ineq, canonical.n_eq,
#    (...)
#     538         initial_constr_penalty, initial_tr_radius,
#     539         factorization_method)
#
# File c:\Users\chris\fyp\venv\lib\site-packages\scipy\optimize\_trustregion_constr\equality_constrained_sqp.py:203, in equality_constrained_sqp(fun_and_constr, grad_and_jac, lagr_hess, x0, fun0, grad0, constr0, jac0, stop_criteria, state, initial_penalty, initial_trust_radius, factorization_method, trust_lb, trust_ub, scaling)
#     201 S = scaling(x)
#     202 # Get projections
# --> 203 Z, LS, Y = projections(A, factorization_method)
#     204 # Compute least-square lagrange multipliers
#     205 v = -LS.dot(c)
#
# File c:\Users\chris\fyp\venv\lib\site-packages\scipy\optimize\_trustregion_constr\projections.py:403, in projections(A, method, orth_tol, max_refin, tol)
#     399 elif method == "SVDFactorization":
#     400     null_space, least_squares, row_space \
#     401         = svd_factorization_projections(A, m, n, orth_tol, max_refin, tol)
# --> 403 Z = LinearOperator((n, n), null_space)
#     404 LS = LinearOperator((m, n), least_squares)
#     405 Y = LinearOperator((n, m), row_space)
#
# File c:\Users\chris\fyp\venv\lib\site-packages\scipy\sparse\linalg\_interface.py:584, in _CustomLinearOperator.__init__(self, shape, matvec, rmatvec, matmat, dtype, rmatmat)
#     581 self.__rmatmat_impl = rmatmat
#     582 self.__matmat_impl = matmat
# --> 584 self._init_dtype()
#
# File c:\Users\chris\fyp\venv\lib\site-packages\scipy\sparse\linalg\_interface.py:182, in LinearOperator._init_dtype(self)
#     180 if self.dtype is None:
#     181     v = np.zeros(self.shape[-1])
# --> 182     self.dtype = np.asarray(self.matvec(v)).dtype
#
# File c:\Users\chris\fyp\venv\lib\site-packages\scipy\sparse\linalg\_interface.py:236, in LinearOperator.matvec(self, x)
#     233 if x.shape != (N,) and x.shape != (N,1):
#     234     raise ValueError('dimension mismatch')
# --> 236 y = self._matvec(x)
#     238 if isinstance(x, np.matrix):
#     239     y = asmatrix(y)
#
# File c:\Users\chris\fyp\venv\lib\site-packages\scipy\sparse\linalg\_interface.py:593, in _CustomLinearOperator._matvec(self, x)
#     592 def _matvec(self, x):
# --> 593     return self.__matvec_impl(x)
#
# File c:\Users\chris\fyp\venv\lib\site-packages\scipy\optimize\_trustregion_constr\projections.py:193, in qr_factorization_projections.<locals>.null_space(x)
#     191 def null_space(x):
#     192     # v = P inv(R) Q.T x
# --> 193     aux1 = Q.T.dot(x)
#     194     aux2 = scipy.linalg.solve_triangular(R, aux1, lower=False)
#     195     v = np.zeros(m)
#
# KeyboardInterrupt:
